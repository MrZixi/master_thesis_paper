# %%
import matplotlib.pyplot as plt

notes = ['D3', '#D3/bE3', 'E3', 'F3', '#F3/bG3', 'G3', '#G3/bA3', 'A3', '#A3/bB3', 'B3', 'C4', '#C4/bD4','D4', '#D4/bE4','E4', 'F4', '#F4/bG4', 'G4', 
         '#G4/bA4', 'A4', '#A4/bB4','B4', 'C5', '#C5/bD5', 'D5', '#D5/bE5', 'E5', 'F5']
# deltas = [47.35, 21.06, 4.02, 1.55, 4.77, 2.36, 5.12, 5.78, 6.03, 5.85, 4.98, 3.42, 4.80, 5.11, 4.92, 4.34, 9.22, 'G4', 
#           12.36, 19.80, 22.19, 23.77, 15.31, 25.96, 28.47, 305.60, 341.25, 383.54]
deltas = [47, 21, 4, 1, 4, 2, 5, 5, 6, 5, 4, 3, 4, 5, 4, 4, 9, 10, 
          12.36, 19.80, 22.19, 23.77, 15.31, 25.96, 28.47, 305.60, 341.25, 383.54]
# for note, delta in zip(notes, deltas):
#     print(note + ' ' + str(delta))
    
plt.ylim((0.0, 400.0))
plt.xticks(range(len(notes)), ['D3', '#D3/bE3', 'E3', 'F3', '#F3/bG3', 'G3', '#G3/bA3', 'A3', '#A3/bB3', 'B3', 'C4', '#C4/bD4','D4', '#D4/bE4','E4', 'F4', '#F4/bG4', 'G4', 
         '#G4/bA4', 'A4', '#A4/bB4','B4', 'C5', '#C5/bD5', 'D5', '#D5/bE5', 'E5', 'F5'], rotation=90, fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel('Notes name')
plt.ylabel('Avg. $\Delta$ Hz')
plt.plot(notes, deltas, 's-', color='black')
plt.savefig('/Users/xiji/Documents/master_thesis_paper/figure/svs/pitch_range_delta.pdf', bbox_inches='tight')
plt.show()
